# %%
import duckdb
con = duckdb.connect(database='insta.duckdb', read_only=True)

# %%
# -------------------------------------------------
# test query
# -------------------------------------------------
sql = """
select * from orders limit 10;
"""
con.execute(sql).df()
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
# 5   3367565       1    prior             6          2                  7
# 6    550135       1    prior             7          1                  9
# 7   3108588       1    prior             8          1                 14
# 8   2295261       1    prior             9          1                 16
# 9   2550362       1    prior            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# ...

# %%
# -------------------------------------------------
# submissions
# -------------------------------------------------
rs = None
sql = """
select * from vsubmission order by order_id;
"""
# %timeit -n1 -r 1 rs = con.execute(sql)
# Out:
# 790 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
sql = """
select * from vsubmission order by order_id;
"""
con.execute(sql).df()
# Out:
#        order_id                                           products
# 0            17                      47766 21463 38777 13107 21709
# 1            34  44663 21137 43504 47766 39475 16083 2596 47792...
# 2           137  23794 5134 2326 25890 41787 44422 29594 24852 ...
# 3           182  41149 13629 47672 29079 39275 8021 5479 9337 1...
# 4           257  38693 30233 29837 4605 24838 27104 13870 45013...
# ...         ...                                                ...
# 74995   3420740  47734 2314 47621 12597 19660 46252 8174 41950 ...
# 74996   3420877  6567 26604 27966 8193 42450 23765 38557 12745 ...
# 74997   3420888  10880 35951 42123 44632 30450 46906 22935 2361...
# 74998   3420989  8865 43210 35004 21616 8151 35951 42450 47229 ...
# 74999   3421054  27370 23286 31231 13375 5818 13493 27429 38448...
#
# [75000 rows x 2 columns]

# %%
# -------------------------------------------------
# submissions
# -------------------------------------------------
sql = """
explain analyse select * from vsubmission order by order_id;
"""
con.execute(sql)
with open("explain.txt", "w") as f:
    f.write(con.fetchall()[0][1])

# %%
con.close()
